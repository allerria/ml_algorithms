# %%
# %load_ext autoreload
# %autoreload 2

# %%
from linear_models import LinearRegressor
import numpy as np

# %%
reg = LinearRegressor()

# %%
reg.W = np.array([1, 1])

# %%
X = np.array([[2, 3], [3, 2]])

# %%
y = [3, 4]

# %%
y_true = np.array([6, 6])

# %%
reg.score(X, y_true)
# Out:
# 4.680000000000005

# %%
reg.fit(X, y)
# Out:
# [ 0.  0.]
# [ 0.24  0.36]
# [ 0.5472  0.5648]
# [ 0.564096  0.590144]
# [ 0.57220608  0.60230912]
# [ 0.7016577  0.6886102]
# [ 0.76379448  0.73003472]
# [ 0.79362013  0.74991849]
# [ 0.80793645  0.7594627 ]
# [ 0.81480828  0.76404392]
# [ 0.74106841  0.65343412]
# [ 0.7974596   0.69102824]
# [ 0.74401928  0.61086777]
# [ 0.71836793  0.57239075]
# [ 0.70605528  0.55392177]
# [ 0.79893416  0.61584102]
# [ 0.84351601  0.64556226]
# [ 0.86491531  0.65982846]
# [ 0.80817003  0.57471054]
# [ 0.78093229  0.53385394]
# [ 0.85167172  0.58101356]
# [ 0.88562665  0.60365017]
# [ 0.83905034  0.53378572]
# [ 0.81669372  0.50025078]
# [ 0.80596254  0.484154  ]
# [ 0.87961906  0.53325836]
# [ 0.85089801  0.49017677]
# [ 0.9069323   0.52753297]
# [ 0.93382876  0.54546394]
# [ 0.89350481  0.48497802]
# [ 0.93544835  0.51294038]
# [ 0.95558126  0.52636232]
# [ 0.96524505  0.53280484]
# [ 0.96988367  0.53589726]
# [ 0.97211021  0.53738162]
# [ 0.97317894  0.53809411]
# [ 0.92832773  0.47081728]
# ...

# %%
reg.W
# Out:
# array([ 1.19999811,  0.20000283])

# %%
y_pred = reg.predict(X)

# %%
y_pred
# Out:
# array([ 3.0000047 ,  3.99999998])
